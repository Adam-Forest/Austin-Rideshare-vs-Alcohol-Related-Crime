# %%
# Dependencies and Setup
import pandas as pd

# Read Crime Data File and store into Pandas data frame
crime_data = pd.read_csv("Crime_Reports.csv", low_memory=False)

# List all columns to see which will be useful
crime_data.columns
# Out:
# Index(['Incident Number', 'Highest Offense Description',
#        'Highest Offense Code', 'Family Violence', 'Occurred Date Time',
#        'Occurred Date', 'Occurred Time', 'Report Date Time', 'Report Date',
#        'Report Time', 'Location Type', 'Address', 'Zip Code',
#        'Council District', 'APD Sector', 'APD District', 'PRA', 'Census Tract',
#        'Clearance Status', 'Clearance Date', 'UCR Category',
#        'Category Description', 'X-coordinate', 'Y-coordinate', 'Latitude',
#        'Longitude', 'Location'],
#       dtype='object')

# %%
#Columns we need: 
#'Highest Offense Description'
#'Occurred Date Time'
#'Occurred Date'
#'Occurred Time' 
#'Address', 
#'Zip Code',
#'Latitude',
#'Longitude'
#'Location

# Create a new data frame with only the columns we need
crime_data = crime_data[["Highest Offense Description",
                            "Occurred Date Time",
                            "Occurred Date",
                            "Occurred Time",
                            "Address",
                            "Zip Code",
                            "Latitude",
                            "Longitude",
                            "Location"]]
crime_data.head()
# Out:
#       Highest Offense Description      Occurred Date Time Occurred Date  \
# 0                           THEFT  07/06/2019 11:30:00 PM    07/06/2019
# 1                      HARASSMENT  07/06/2019 09:28:00 PM    07/06/2019
# 2                   FRAUD - OTHER  07/06/2019 09:07:00 PM    07/06/2019
# 3                           THEFT  07/06/2019 09:01:00 PM    07/06/2019
# 4  ASSAULT W/INJURY-FAM/DATE VIOL  07/06/2019 08:30:00 PM    07/06/2019
#
#    Occurred Time                          Address  Zip Code   Latitude  \
# 0         2330.0  10100 N CAPITAL OF TEXAS HWY SB   78759.0  30.390726
# 1         2128.0           2100 BARTON SPRINGS RD   78746.0  30.267764
# 2         2107.0                1900 GUADALUPE ST   78705.0  30.282082
# 3         2101.0         11229 WINDERMERE MEADOWS   78759.0  30.424620
# 4         2030.0                   8717 FENTON DR   78736.0  30.237662
#
#    Longitude                     Location
# 0 -97.736370  (30.39072645, -97.73637025)
# 1 -97.767909  (30.26776386, -97.76790929)
# 2 -97.742459  (30.28208159, -97.74245901)
# 3 -97.773081   (30.42461961, -97.7730808)
# 4 -97.903608  (30.23766171, -97.90360808)

# %%
# Drop the NA values
crime_data=crime_data.dropna()

# Create a new column to format the date and time to match our ride share data
crime_data["Date"]=pd.to_datetime(crime_data["Occurred Date Time"])

# Filter the data by date using the start and end date from our ride share data
ride_start_date = "2016-06-04 00:10:19-05:00"
ride_end_date = "2017-04-13 18:56:41-05:00"
filter = (crime_data['Date'] > ride_start_date) & (crime_data['Date'] <= ride_end_date)
crime_data=crime_data.loc[filter]

# Print the min and max date to make sure it worked
print(crime_data["Date"].max())
print(crime_data["Date"].min())
# Out:
# 2017-04-13 18:55:00
# 2016-06-04 00:13:00

# %%
# List all of the types of crimes so that we can filter by only the alcohol related crimes
crime_data['Highest Offense Description'].unique()
# Out:
# array(['FAMILY DISTURBANCE', 'POSSESSION OF MARIJUANA',
#        'THEFT BY SHOPLIFTING', 'WARRANT ARREST NON TRAFFIC',
#        'CRIMINAL MISCHIEF', 'THEFT', 'VIOL CITY ORDINANCE - DOG',
#        'DISTURBANCE - OTHER', 'CRASH/FAIL STOP AND RENDER AID',
#        'ASSAULT BY THREAT', 'GRAFFITI', 'THEFT FROM PERSON',
#        'BURGLARY OF VEHICLE', 'CHILD CUSTODY INTERFERE',
#        'CIVIL DISTURBANCE/DEMO', 'AGG ASLT STRANGLE/SUFFOCATE',
#        'ASSAULT BY CONTACT', 'TERRORISTIC THREAT',
#        'BURGLARY NON RESIDENCE', 'CRIMINAL TRESPASS/TRANSIENT',
#        'TERRORISTIC THREAT-FAM/DAT VIO', 'EVADING VEHICLE',
#        'ASSAULT WITH INJURY', 'FAILURE TO IDENTIFY',
#        'VIOL CITY ORDINANCE - OTHER', 'ASSAULT BY CONTACT FAM/DATING',
#        'PROTECTIVE ORDER', 'AGG ASSAULT', 'HARASSMENT',
#        'BURGLARY OF RESIDENCE', 'CHILD ENDANGERMENT- ABANDONMEN',
#        'DATING DISTURBANCE', 'CRIMINAL TRESPASS',
#        'ASSAULT W/INJURY-FAM/DATE VIOL', 'PUBLIC INTOXICATION',
#        'SUSPICIOUS PERSON', 'ASSAULT ON PUBLIC SERVANT',
#        'CRED CARD ABUSE - OTHER', 'IDENTITY THEFT-TAX RETURNS',
#        'HARBORING RUNAWAY CHILD', 'FRAUD - OTHER', 'FEDERAL VIOL/OTHER',
#        'DOC OFFENSIVE GESTURE', 'RUNAWAY CHILD', 'IDENTITY THEFT',
#        'DOC FIGHTING', 'FALSE REPORT TO PEACE OFFICER',
#        'POSS CONTROLLED SUB/NARCOTIC', 'DEBIT CARD ABUSE',
#        'POSS OF DRUG PARAPHERNALIA', 'CRED CARD ABUSE BY FORGERY',
#        'FAMILY DISTURBANCE/PARENTAL', 'CUSTODY ARREST TRAFFIC WARR',
#        'THEFT OF BICYCLE', 'THEFT FROM AUTO', 'AIRPORT - FEDERAL VIOL',
#        'ROBBERY BY ASSAULT', 'DWI', 'POSS OF FIREARM BY FELON',
#        'POSS CONTROLLED SUB/SYN NARC', 'DWI 2ND', 'THEFT OF TRAILER',
#        'FORGERY AND PASSING', 'UNLAWFUL CARRYING WEAPON',
#        'VIOL OF EMERG PROTECTIVE ORDER', 'FORGERY OF IDENTIFICATION',
#        'AUTO THEFT', 'AGG ROBBERY/DEADLY WEAPON',
#        'AGG ASSAULT FAM/DATE VIOLENCE', 'POSS SYNTHETIC MARIJUANA',
#        'UNLAWFUL RESTRAINT FAM/DAT VIO', 'THEFT OF SERVICE',
#        'EVADING / FOOT', 'INJURY TO CHILD',
#        'DOC DISPLAY GUN/DEADLY PUB PLC', 'TAMPERING WITH EVIDENCE',
#        'CRIMINAL TRESPASS/HOTEL', 'DEL CONTROLLED SUB/NARCOTIC',
#        'ASSAULT BY THREAT FAM/DATING', 'POSS/PROMO CHILD PORNOGRAPHY',
#        'ONLINE IMPERSONATION', 'STALKING',
#        'FELONY ENHANCEMENT/ASSLT W/INJ', 'VIOL OF PROTECTIVE ORDER',
#        'CRUELTY TO ANIMALS', 'SOLICITATION - BEGGING', 'THEFT OF METAL',
#        'DAMAGE CITY VEHICLE', 'DAMAGE CITY PROP', 'DWI  .15 BAC OR ABOVE',
#        'DRIVING WHILE INTOX / FELONY', 'APPLIC TO REVOKE PROBATION',
#        'THEFT OF LICENSE PLATE', 'DWI - CHILD PASSENGER',
#        'VIOL STATE LAW - OTHER', 'FORGERY - OTHER',
#        'VOCO - ALCOHOL  CONSUMPTION', 'BREACH OF COMPUTER SECURITY',
#        'BURG NON RESIDENCE SHEDS', 'AIRPORT PLACES WEAPON PROHIBIT',
#        'FORGERY BY MAKING', 'EXPLOSIVE ORDNANCE DISPOSAL',
#        'RESISTING ARREST OR SEARCH', 'THEFT- APPROPRIATE STOLEN PROP',
#        'DUI - AGE 17 TO 20', 'INJURY TO CHILD (CARE/CUSTODY)',
#        'VIOL CITY ORDINANCE - AIRPORT', 'RECKLESS DAMAGE',
#        'URINATING IN PUBLIC PLACE', 'ONLINE SOLICITATION OF A MINOR',
#        'FALSE STATEMENT -OBTAIN CREDIT', 'DOC EXPOSURE', 'DEADLY CONDUCT',
#        'ARSON', 'VIOL OF BOND CONDITIONS', 'DOC WINDOW PEEPING-RESIDENCE',
#        'VIOL CITY ORDINANCE - WRECKER', 'POSS OF PROHIBITED WEAPON',
#        'AGG ASSAULT WITH MOTOR VEH', 'INTER EMERG PHONECALL FAM/DATE',
#        'DWI - DRUG RECOGNITION EXPERT', 'RENTAL CAR/FAIL TO RETURN',
#        'DEL SYNTHETIC MARIJUANA', 'CRED CARD ABUSE - EXPIR-CANCEL',
#        'MISUSE OF OFFICIAL INFO', 'HARASSMENT OF A PUBLIC SERVANT',
#        'AGG ASSAULT ON PUBLIC SERVANT', 'PROSTITUTION',
#        'ROBBERY BY THREAT', 'EVADING / VEHICLE PURSUIT',
#        'VIOL CITY ORDINANCE - SMOKING', 'POSS CONTROLLED SUB/OTHER',
#        'VIOL GLASS CONTAINER', 'INDECENT EXPOSURE',
#        'MISAPPLY FIDUCIARY PROP', 'CRIMINAL MISCHIEF BY ARSON',
#        'COUNTERFEITING', 'CAMPING IN PARK', 'MURDER',
#        'DOC DISCHARGE GUN - PUB ROAD', 'THEFT OF AUTO PARTS',
#        'PUBLIC LEWDNESS', 'THEFT BY CHECK',
#        'AGG ASLT W/MOTOR VEH FAM/DAT V', 'FALSE ALARM OR REPORT',
#        'HINDERING APPREHENSION', 'DOC UNREASONABLE NOISE',
#        'MONEY LAUNDERING', 'ASSAULT - SCHOOL PERSONNEL',
#        'INJURY DISABLED INDIVIDUAL', 'NUISANCE ABATEMENT',
#        'CRASH/INTOXICATION ASSAULT', 'TAMPERING WITH GOV RECORD',
#        'OBTAIN CONTROLLED SUB BY FRAUD', 'RETALIATION',
#        'AGG ASLT ENHANC STRANGL/SUFFOC', 'FALSE REPORT TO CPS',
#        'POSS OF GAMBLING PARAPHERNALIA', 'HINDER SECURED CREDITORS',
#        'FORGERY BY ALTERATION', 'KIDNAPPING',
#        'INJ TO ELDERLY   FAM/DATE VIOL', 'POSS OF ALCOHOL - AGE 17 TO 20',
#        'CRIMINAL SOLICITATION OF MINOR', 'DOC DISCHARGE GUN - PUB PLACE',
#        'CRIMINAL TRESPASS/IN VEHICLE', 'FRAUD DESTRUCTION OF A WRITING',
#        'TRAFFICKING OF PERSONS', 'LIQUOR LAW VIOLATION/OTHER',
#        'POSS DANG DRUG', 'DOC ABUSIVE LANGUAGE', 'LITTERING',
#        'VIOL TEMP EX PARTE  ORDER', 'DEL MARIJUANA',
#        'THEFT FROM BUILDING', 'ESCAPE FROM CUSTODY', 'OBSCENITY',
#        'PROBATION VIOL', 'INTERFERE W PO SERVICE ANIMALS', 'PAROLE VIOL',
#        'DEL CONTROLLED SUB/SYN NARC', 'INJURY TO ELDERLY PERSON',
#        'DUMPING REFUSE NEAR HIGHWAY', 'BOMB THREAT',
#        'PROMOTION OF PROSTITUTION', 'BURG OF RES - FAM/DATING ASLT',
#        'DOC ABUSE OR THREAT', 'THEFT BY EMBEZZLEMENT',
#        'TAMPERING WITH WITNESS', 'AIRPORT - BREACH OF SECURITY',
#        'IMPERSONATING PUBLIC SERVANT', 'INTERFERING W/EMERG PHONE CALL',
#        'VIOL OF COURT ORDER-NON EPO-PO', 'POCKET PICKING',
#        'INJ/CHILD FV (NO CARE/CUSTODY)', 'VOCO SOLICITATION PROHIBIT',
#        'ABUSE OF OFFICIAL CAPACITY', 'VOCO AMPLIFIED MUSIC/VEHICLE',
#        'UNLAWFUL RESTRAINT', 'UNLAWFUL CARRY-LIC HOLDER',
#        'VIOL CITY ORDINANCE - CURFEW', 'BURGLARY OF COIN-OP MACHINE',
#        'DOC WINDOW PEEPING - HOTEL', 'TAKE WEAPON FRM POLICE OFFICER',
#        'ILLUMIN AIRCRAFT INTENSE LIGHT', 'DEL CONTROLLED SUB/OTHER',
#        'GAMBLING', 'DISTRIB HARMFUL MATERIAL MINOR',
#        'VIOL STAY AWAY ORDER', 'FRAUD FILING FINANCE STATEMENT',
#        'INJ TO DISABLED  FAM/DATE VIOL', 'GAMBLING PROMOTION',
#        'MISREP AGE BY MINOR', 'WEAPON VIOL - OTHER',
#        'POSS OF ALCOHOL-AGE 16 & UNDER', 'PIGEON DROP',
#        'VIOL CITY ORDINANCE -FIREWORK', 'VIOL CITY ORDINANCE - SOUND',
#        'AGG ROBBERY BY ASSAULT', 'PROWLER', 'DEL OF ALCOHOL TO MINOR',
#        'THEFT BY FALSE PRETEXT/BUNCO', 'OFFICIAL OPPRESSION',
#        'CRIM NEG HOMICIDE/NON TRAFFIC', 'OBSCENE DISPLAY - DISTRIBUTION',
#        'DEADLY CONDUCT FAM/DATE VIOL', 'VIOL OF PARK CURFEW',
#        'TOBACCO VIOL - AGE 17', 'CRIMINAL SOLICITATION',
#        'VIOL CITY ORDINANCE -  GAME RM', 'TRADEMARK COUNTERFEITING',
#        'PURSE SNATCHING', 'TRUANCY', 'INHALANT ABUSE',
#        'CRASH/INTOX MANSLAUGHTER', 'TOBACCO VIOL - UNDER AGE 17',
#        'DANG DRUG VIOL - OTHER', 'CONTROLLED SUB VIOL - OTHER',
#        'AGG KIDNAPPING', 'INTERFERENCE PUBLIC DUTIES',
#        'SIT AND LIE ORDINANCE VIOL', 'RECKLESS CONDUCT',
#        'POSS CRIMINAL INSTRUMENT', 'MAKING TOBACCO AVAIL TO MINOR',
#        'THEFT BY EXTORTION', 'THEFT/TILL TAPPING',
#        'THEFT OF HEAVY EQUIPMENT', 'KIDNAPPING FAM VIO', 'MANSLAUGHTER',
#        'UCW LICENSE PREMISE', 'BAIL JUMPING/FAIL TO APPEAR',
#        'AGG PROMOTION OF PROSTITUTION', 'DUI - AGE 16 AND UNDER',
#        'VIOL CITY ORDINANCE - TAXI', 'FORGERY- CERTIFICATE OF TITLE',
#        'ISSUANCE OF BAD CHECK', 'DOC WINDOW PEEPING - PUB AREA',
#        'SMUGGLING ILLEGAL ALIEN', 'CAPITAL MURDER',
#        'VIOL WATER SAFETY ACT', 'BANK KITING',
#        'TAMPERING WITH CONSUMER PROD', 'KEEPING GAMBLING PLACE',
#        'IMMIGRATION HOLD/ARREST', 'ILLEGAL LABELLING OF RECORDING',
#        'DISPOSAL OF SOLID WASTE', 'CRIMINAL CONSPIRACY',
#        'CONTEMPT OF COURT', 'PERJURY', 'BOATING WHILE INTOXICATED',
#        'POSSESSION OF FORGED WRITING', 'SECURING EXEC-DOC BY DECEPTION'],
#       dtype=object)

# %%
#Filter only alcohol related crimes from Highest Offense Description
alcohol_related = crime_data.loc[(crime_data["Highest Offense Description"] == 'PUBLIC INTOXICATION') |
                                 (crime_data["Highest Offense Description"] == 'DWI') | 
                                 (crime_data["Highest Offense Description"] == 'DWI 2ND') |
                                 (crime_data["Highest Offense Description"] == 'DWI  .15 BAC OR ABOVE') |
                                 (crime_data["Highest Offense Description"] == 'DRIVING WHILE INTOX / FELONY') |
                                 (crime_data["Highest Offense Description"] == 'VOCO - ALCOHOL  CONSUMPTION') |
                                 (crime_data["Highest Offense Description"] == 'DUI - AGE 17 TO 20') |
                                 (crime_data["Highest Offense Description"] == 'CRASH/INTOXICATION ASSAULT') |
                                 (crime_data["Highest Offense Description"] == 'LIQUOR LAW VIOLATION/OTHER') |
                                 (crime_data["Highest Offense Description"] == 'POSS OF ALCOHOL - AGE 17 TO 20') |
                                 (crime_data["Highest Offense Description"] == 'POSS OF ALCOHOL-AGE 16 & UNDER') |
                                 (crime_data["Highest Offense Description"] == 'DEL OF ALCOHOL TO MINOR') |
                                 (crime_data["Highest Offense Description"] == 'CRASH/INTOX MANSLAUGHTER') |
                                 (crime_data["Highest Offense Description"] == 'DUI - AGE 16 AND UNDER') |
                                 (crime_data["Highest Offense Description"] == 'BOATING WHILE INTOXICATED'), :]
alcohol_related.head()
# Out:
#        Highest Offense Description      Occurred Date Time Occurred Date  \
# 232141         PUBLIC INTOXICATION  04/13/2017 02:10:00 PM    04/13/2017
# 232249                         DWI  04/13/2017 04:03:00 AM    04/13/2017
# 232259                         DWI  04/13/2017 02:24:00 AM    04/13/2017
# 232266                         DWI  04/13/2017 01:41:00 AM    04/13/2017
# 232270                         DWI  04/13/2017 01:25:00 AM    04/13/2017
#
#         Occurred Time                                 Address  Zip Code  \
# 232141         1410.0  MANCHACA RD / W BEN WHITE BLVD SVRD EB   78745.0
# 232249          403.0                 CONGRESS AVE / W 2ND ST   78701.0
# 232259          224.0                            9200 WALL ST   78754.0
# 232266          141.0                            217 E 4TH ST   78701.0
# 232270          125.0                W 51ST ST / N LAMAR BLVD   78751.0
#
#          Latitude  Longitude                     Location                Date
# 232141  30.229632 -97.788527  (30.22963221, -97.78852736) 2017-04-13 14:10:00
# 232249  30.264319 -97.744203  (30.26431941, -97.74420303) 2017-04-13 04:03:00
# 232259  30.343829 -97.669528  (30.34382873, -97.66952842) 2017-04-13 02:24:00
# 232266  30.265491 -97.741203   (30.2654909, -97.74120279) 2017-04-13 01:41:00
# 232270  30.318767 -97.730828   (30.3187666, -97.73082849) 2017-04-13 01:25:00

# %%
#Convert date to datetime object
alcohol_related["Date"]=pd.to_datetime(alcohol_related["Date"], utc=True)

#Extract the month
alcohol_related['Month'] = alcohol_related['Date'].dt.month
alcohol_related.head()
# Out:
# /Users/allison/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/allison/anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#        Highest Offense Description      Occurred Date Time Occurred Date  \
# 232141         PUBLIC INTOXICATION  04/13/2017 02:10:00 PM    04/13/2017
# 232249                         DWI  04/13/2017 04:03:00 AM    04/13/2017
# 232259                         DWI  04/13/2017 02:24:00 AM    04/13/2017
# 232266                         DWI  04/13/2017 01:41:00 AM    04/13/2017
# 232270                         DWI  04/13/2017 01:25:00 AM    04/13/2017
#
#         Occurred Time                                 Address  Zip Code  \
# 232141         1410.0  MANCHACA RD / W BEN WHITE BLVD SVRD EB   78745.0
# 232249          403.0                 CONGRESS AVE / W 2ND ST   78701.0
# 232259          224.0                            9200 WALL ST   78754.0
# 232266          141.0                            217 E 4TH ST   78701.0
# 232270          125.0                W 51ST ST / N LAMAR BLVD   78751.0
#
#          Latitude  Longitude                     Location  \
# 232141  30.229632 -97.788527  (30.22963221, -97.78852736)
# 232249  30.264319 -97.744203  (30.26431941, -97.74420303)
# 232259  30.343829 -97.669528  (30.34382873, -97.66952842)
# 232266  30.265491 -97.741203   (30.2654909, -97.74120279)
# 232270  30.318767 -97.730828   (30.3187666, -97.73082849)
#
#                             Date  Month
# 232141 2017-04-13 14:10:00+00:00      4
# 232249 2017-04-13 04:03:00+00:00      4
# 232259 2017-04-13 02:24:00+00:00      4
# 232266 2017-04-13 01:41:00+00:00      4
# 232270 2017-04-13 01:25:00+00:00      4

# %%
# Save the cleaned CSV
alcohol_related.to_csv("Crime_Reports_Clean2.csv", encoding="utf-8")
